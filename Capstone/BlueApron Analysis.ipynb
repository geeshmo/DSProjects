# %% [markdown]
# # Applied Linear Regression Models to Predict Engagement
# * Engagement was calculated with (Comments + likes) + (Replies + likes)

# %%
import numpy as np
import pandas as pd
import time
import pickle

import matplotlib.pyplot as plt
# Out:
# /Users/Guillermo/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# # Model 1
#
# * "Comment" column included and normalized

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression



with open('cleaneddata.pkl', 'r') as picklefile:
    data = pickle.load(picklefile)
datay = data['Engagement'].copy()
data3=data.drop(['Recipe_URL', 'Ingredients','Recipe_Name','Engagement'], axis =1).copy()
nc = ['Comments']
data3.ix[:, nc] = (data3.ix[:, nc] - data3.ix[:, nc].min())\
                   / (data3.ix[:, nc].max() - data3.ix[:, nc].min())

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
       data3, datay, test_size=0.30, random_state =101)

# %%
y = StandardScaler()
df7= y.fit_transform(data3)

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()

lm.fit(X_train, y_train)

print(lm.intercept_)

coeff_df = pd.DataFrame(lm.coef_.T,X_train.columns,columns=['Coefficient'])
coeff_df.sort(columns='Coefficient',ascending=False)
# Out:
# -2.18161588779
# /Users/Guillermo/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                                                     Coefficient
#  Kimchi Spice Blend (Gochugaru, Granulated Suga...   309.309945
# Comments                                             271.102795
# Round Pugliese Bread\n\n                             195.397140
# Cornish Game Hen\n\n                                 193.458052
#  Whole  Rosemary\n\n                                 170.600693
#   Porcini Mushrooms\n\n                              146.234839
#  Mexican Spice Blend (Ancho Chile Powder, Sweet...   136.647429
# Plum Tomato\n\n                                      128.345656
#  Chicken Tarkari Spice Blend (Curry Powder, Gro...   125.117723
#  Endives\n\n                                         119.715804
# Jalapeño Pepper\n\n                                  109.044466
#  Fregola Sarda Spice Blend (Ground Turmeric, Sw...   107.584152
#  Creamy Casserole Spice Blend (Ground Yellow Mu...   106.335248
#  Kale Slaw Spice Blend (Whole Caraway Seeds, Wh...   106.171045
#  Baby Romaine Lettuce\n\n                            104.387014
#  Soba Noodles\n\n                                    102.438553
#  Catfish Taco Spice Blend (All-Purpose Flour, A...    96.185790
#  Quesadilla Spice Blend (Ground Cumin, Smoked P...    94.505380
#  Basmati Rice\n\n                                     94.105576
# Russet Potato\n\n                                     92.710170
#  Pecorino Cheese\n\n                                  90.819789
#  Fresh Chestnut Pasta\n\n                             90.595168
#  Pickle Chips\n\n                                     80.298479
#  Shiitake Mushrooms\n\n                               79.901565
#  Tempura Mix\n\n                                      79.655841
#  White Mushrooms\n\n                                  79.136673
#  Yuzu Kosho\n\n                                       78.891050
#  Carne Molida Spice Blend (Ancho Chile Powder, ...    78.570341
#  Indian Cauliflower Spice Blend (Smoked Paprika...    76.957787
#  Kale\n\n                                             75.761384
# ...                                                         ...
#  Squash Quesadilla Spice Blend (Ancho Chile Pow...   -72.011423
#  Gochugaru (Korean Chile Flakes)\n\n                 -74.014871
#  Crispy Catfish Spice Blend (Onion Powder, Garl...   -75.213392
#  Shrimp Boil Spice Blend (Sweet Paprika, Celery...   -76.390857
# Bulb Fennel\n\n                                      -76.391342
#  Frisée\n\n                                          -76.444172
#  Soy Sauce\n\n                                       -77.039579
# Premium Top Round Steaks\n\n                         -78.527976
# Steak\n\n                                            -78.869598
# Eggs\n\n                                             -80.986022
#  Fresh Basil Fettuccine Pasta\n\n                    -81.118351
#  Tomato Rice Spice Blend (Smoked Paprika, Groun...   -82.882826
#  Pork Burger Spice Blend (Ground Fennel Seeds, ...   -83.933878
#  Green Peppercorns\n\n                               -84.354366
#  Zucchini\n\n                                        -84.428745
#  Arborio Rice\n\n                                    -84.624192
#  Breadcrumbs\n\n                                     -85.316313
#  Sorrel Leaves\n\n                                   -85.630974
#  Curly Egg Noodles\n\n                               -89.063371
#  Eggplant Bake Spice Blend (Garlic Powder,  Ale...   -89.968226
#  Togarashi\n\n                                       -91.397334
#  Matcha Powder\n\n                                   -93.149319
#  Chickpea Flour\n\n                                  -93.732694
#   Oregano\n\n                                        -99.692142
#  Tetrazzini Spice Blend (Sweet Paprika, Whole O...  -102.580411
#  Acorn Squash\n\n                                   -104.184562
# Limes\n\n                                           -109.258288
# Fairy Tale Eggplants\n\n                            -111.726111
#  Braised Vegetable Spice Blend (Herbes De Prove...  -168.999427
# Bird's Eye Chile\n\n                                -239.796952
#
# [1155 rows x 1 columns]

# %%
predictions = lm.predict(X_test)
#r2 meansqaured error

# %%
print predictions[0:20]
# Out:
# [ 123.49082138   30.98272929   31.90738974 -144.17088059  335.61983025
#    40.9795262   236.65548732  279.68535049  -46.23407815  120.83683338
#    80.30645308   26.62597143   -2.34987714  209.87976501   92.50383419
#    88.72446106  -22.17985993  228.45701958   60.81001215   55.74108856]

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test.values,predictions)
# Out:
# 8002.1241261475834

# %% [markdown]
# ## RMSE was 90 but this was misleading, the dataset did not have comments seperated out and comments are already factored into the engagement score

# %% [markdown]
# # Model 2
# * with out "Comments"

# %%
datay2 = data['Engagement'].copy()
data32 =data.drop(['Recipe_URL', 'Ingredients','Recipe_Name','Comments', 'Engagement'], axis =1).copy()

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(
       data32, datay, test_size=0.30, random_state =101)

# %%
df7= y.fit_transform(data32)


lm.fit(X3_train, y3_train)

print(lm.intercept_)

coeff_df2 = pd.DataFrame(lm.coef_.T,X_train.columns,columns=['Coefficient'])
coeff_df2.sort(columns='Coefficient',ascending=False)

predictions = lm.predict(X3_test)
mean_squared_error(y3_test.values,predictions)
# Out:
# 180.804010558
# /Users/Guillermo/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 18537.130659155184

# %% [markdown]
# ## First Model ran with an RMSE of 137

# %% [markdown]
# # Model 3 Combined with Stacking regressor
#
# * "Comment" column exclude since its intricately related to Engagement

# %%
datay2 = data['Engagement'].copy()
data32 =data.drop(['Recipe_URL', 'Ingredients','Recipe_Name','Comments', 'Engagement'], axis =1).copy()

# %%
from sklearn.cross_validation import train_test_split
X2_train, X2_test, y2_train, y2_test = train_test_split(
       data32, datay, test_size=0.30, random_state =101)

# %%
from mlxtend.regressor import StackingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.linear_model import Lasso
from sklearn.cross_validation import KFold
from sklearn import cross_validation

# %%
lr = LinearRegression()
svr_lin = SVR(kernel='linear')
ridge = Ridge(random_state=1)
svr_rbf = SVR(kernel='rbf')

stregr = StackingRegressor(regressors=[svr_lin, lr, ridge], 
                           meta_regressor=svr_rbf)

# Training the stacking classifier

stregr.fit(X2_train, y2_train)
stregr.predict(X2_test)

# Evaluate and visualize the fit

print("Mean Squared Error: %.4f"
      % np.mean((stregr.predict(X2_train) - y2_train) ** 2))
print('Variance Score: %.4f' % stregr.score(X2_train, y2_train))
'''
with plt.style.context(('seaborn-whitegrid')):
    plt.scatter(X, y, c='lightgray')
    plt.plot(X, stregr.predict(X), c='darkgreen', lw=2)

plt.show()'''
# Out:
# Mean Squared Error: 9812.2164
# Variance Score: -0.2632
# "\nwith plt.style.context(('seaborn-whitegrid')):\n    plt.scatter(X, y, c='lightgray')\n    plt.plot(X, stregr.predict(X), c='darkgreen', lw=2)\n\nplt.show()"

# %% [markdown]
# ### RMSE

# %%
np.sqrt(9812.2164)
# Out:
# 99.056632286788343

# %% [markdown]
# # Model 4
# * ridge reggresion
# * lasso
# * gridsearch

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import Lasso

# Initializing models

lr = LinearRegression()
svr_lin = SVR(kernel='linear')
ridge = Ridge(random_state=1)
lasso = Lasso(random_state=1)
svr_rbf = SVR(kernel='rbf')
regressors = [svr_lin, lr, ridge, lasso]
stregr = StackingRegressor(regressors=regressors, 
                           meta_regressor=svr_rbf)

params = {'lasso__alpha': [0.1, 1.0, 10.0],
          'ridge__alpha': [0.1, 1.0, 10.0],
          'svr__C': [0.1, 1.0, 10.0],
          'meta-svr__C': [0.1, 1.0, 10.0, 100.0],
          'meta-svr__gamma': [0.1, 1.0, 10.0]}

grid = GridSearchCV(estimator=stregr, 
                    param_grid=params, 
                    cv=5,
                    refit=True)
grid.fit(X2_train, y2_train)

for params, mean_score, scores in grid.grid_scores_:
        print("%0.3f +/- %0.2f %r"
              % (mean_score, scores.std() / 2.0, params))
# Out:
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.285 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.287 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.286 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.287 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.287 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.199 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.241 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.224 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.232 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.252 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.244 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.246 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.257 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.254 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.263 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.262 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.004 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.003 +/- 0.00 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.003 +/- 0.00 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# 0.002 +/- 0.00 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.007 +/- 0.00 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.007 +/- 0.00 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.002 +/- 0.00 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.012 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.013 +/- 0.00 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.020 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.020 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.020 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 0.1, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.291 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.291 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.291 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.283 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.286 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.285 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.286 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.287 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.192 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.240 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.227 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.238 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.254 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.250 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.242 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.256 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.251 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.263 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.263 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.265 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# 0.011 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# 0.005 +/- 0.00 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# 0.002 +/- 0.00 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# 0.007 +/- 0.00 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.005 +/- 0.00 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.009 +/- 0.00 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.000 +/- 0.00 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.010 +/- 0.00 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.010 +/- 0.00 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.019 +/- 0.00 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.020 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.021 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 1.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.286 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.290 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.291 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.291 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.291 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.291 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.291 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.292 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 0.1, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.225 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.267 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.251 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.273 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.281 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.278 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.279 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.284 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.283 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.287 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.287 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.286 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.287 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.288 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.289 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 1.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# 0.004 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.106 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.082 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.102 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.192 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.164 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.123 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.199 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.183 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.227 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.254 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.225 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.255 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.260 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.252 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.255 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.262 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.254 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.262 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.263 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.257 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.263 +/- 0.02 {'ridge__alpha': 1.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.264 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.262 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 10.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.160 +/- 0.06 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.026 +/- 0.02 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.060 +/- 0.03 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.043 +/- 0.04 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# 0.012 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.013 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.024 +/- 0.02 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# 0.023 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# -0.010 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 0.1}
# Mean Squared Error: 7974.4175
# 0.006 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.008 +/- 0.00 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.004 +/- 0.00 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.007 +/- 0.00 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.016 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.011 +/- 0.00 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.004 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.017 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.013 +/- 0.00 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 1.0}
# Mean Squared Error: 7974.4175
# -0.019 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.021 +/- 0.01 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.015 +/- 0.00 {'ridge__alpha': 0.1, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.021 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.020 +/- 0.01 {'ridge__alpha': 1.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.021 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 0.1, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.022 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 1.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# -0.020 +/- 0.01 {'ridge__alpha': 10.0, 'meta-svr__C': 100.0, 'lasso__alpha': 10.0, 'svr__C': 10.0, 'meta-svr__gamma': 10.0}
# Mean Squared Error: 7974.4175
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-fd4b7317106e> in <module>()
#      31         print("Mean Squared Error: %.4f"
#      32       % np.mean((grid.predict(X2_test) - y2_test) ** 2))
# ---> 33 print('Variance Score: %.4f' % grid.score(X, y))
#
# NameError: name 'X' is not defined

# %%
      print("Mean Squared Error: %.4f"
      % np.mean((grid.predict(X2_test) - y2_test) ** 2))
print('Variance Score: %.4f' % grid.score(X2_test, y2_test))
# Out:
# Mean Squared Error: 7974.4175
# Variance Score: -0.0148

# %% [markdown]
# # Model 5 previous models with crossvalidation

# %%
#X3_train, X3_test, y3_train, y3_test
from mlxtend.classifier import StackingCVClassifier
lr = LinearRegression()
svr_lin = SVR(kernel='linear')
ridge = Ridge(random_state=1)
svr_rbf = SVR(kernel='rbf')
lasso = Lasso(random_state=1)

stregr = StackingRegressor(regressors=[svr_lin, lr, ridge, lasso], 
                           meta_regressor=svr_rbf)

stregr.fit(data32, datay2)
stregr.predict(data32)

print("Mean Squared Error: %.4f"
      % np.mean((stregr.predict(data32) - datay) ** 2))
print('Variance Score: %.4f' % stregr.score(data32, datay2))

print np.sqrt(np.mean((stregr.predict(data32) - datay) ** 2))
# Out:
# Mean Squared Error: 9804.9740
# Variance Score: -0.2576
# 99.0200688571

# %% [markdown]
# # Model 6

# %%
from sklearn.svm import SVR
from sklearn.grid_search import GridSearchCV

from sklearn.kernel_ridge import KernelRidge
svr = GridSearchCV(SVR(kernel='linear', gamma=0.1), cv=5,
                   param_grid={"C": [1e0, 1e1, 1e2, 1e3],
                               "gamma": np.logspace(-2, 2, 5)})

kr = GridSearchCV(KernelRidge(kernel='rbf', gamma=0.1), cv=5,
                  param_grid={"alpha": [1e0, 0.1, 1e-2, 1e-3],
                              "gamma": np.logspace(-2, 2, 5)})
kr.fit(X2_train,y2_train)
svr.fit(X2_train,y2_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#   kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'C': [1.0, 10.0, 100.0, 1000.0], 'gamma': array([  1.00000e-02,   1.00000e-01,   1.00000e+00,   1.00000e+01,
#          1.00000e+02])},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
from sklearn.metrics import mean_squared_error

predictionsvr = svr.predict(X2_test)
print np.sqrt(mean_squared_error(y2_test.values,predictionsvr))
predictionkr = kr.predict(X2_test)
print np.sqrt(mean_squared_error(y2_test.values,predictionkr))
# Out:
# 81.7144958689
# 80.8309941391

# %% [markdown]
# ### Best MSE with a score 82 and 81

# %% [markdown]
# # Models 7 & 8

# %%
svr2 = SVR(kernel='linear', gamma =0.1)
svr2.fit(X2_train,y2_train)
predictionsvr2 = svr2.predict(X2_test)
print np.sqrt(mean_squared_error(y2_test.values,predictionsvr2))
# Out:
# 92.8105204745

# %%
svr3 = SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
  kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
svr3.fit(X2_train,y2_train)
predictionsvr3 = svr3.predict(X2_test)
print np.sqrt(mean_squared_error(y2_test.values,predictionsvr3))
# Out:
# 92.8105204745

# %% [markdown]
# ### Additonal Models did not run as well
