# %% [markdown]
# # Random Walk Creation
# ## Random walks can be used to model Stock Markets and Stock movements
# ### Part One Simulates the Random Walk

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

def Randomwalk(L, R):
    walk = np.random.uniform(low = -1, high =1, size=(R,L))
    walk[:,0]= 0
    walk2 = walk.cumsum(axis = 1)
    return walk.cumsum(axis = 1)
R, L = raw_input("Please pick two numbers of silumated random walks and the length( walk, length)").split()

R = int(R)
L = int(L)
    
fig = plt.figure(figsize = (5,10))
ax1 = fig.add_subplot()

walk_array = Randomwalk(R,L)

#walk2 = Randomwalk(1000,10000)
# %matplotlib inline
plt.plot(Randomwalk(R,L).T);
# Out:
# Please pick two numbers of silumated random walks and the length( walk, length)100 100

# %% [markdown]
# ## Creation Histogram of Distribution of Final Positions of Random Walk

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline 
final = [walk_array[i, L-1] for i in range(len(walk_array))]

print type(final)

fig = plt.figure(figsize = (8,5))
#fig, ax = plt.subplots(figsize=(8,5))
print min(final)
print max(final)
bins = np.arange(min(final), max(final), 5)
print bins
print  "variance: {0}, Mean{1}".format(np.mean(final), np.var(final))
plt.hist(final, bins, normed = true) #, bins = np.arange(min(final), max(final) +1, 20)) #normed= true)

plt.show()
# Out:
# <type 'list'>
# -14.2729270073
# 15.6225114881
# [-14.27292701  -9.27292701  -4.27292701   0.72707299   5.72707299
#   10.72707299]
# variance: -0.684330157049, Mean31.0293827901

# %% [markdown]
# ## Creation of Doubleslit Function to Filter Walks

# %%
walk = np.random.uniform(low = -1, high = 1, size = (10000, 1000))

# %%
import numpy as np
walk = np.random.uniform(low = -1, high = 1, size = (2, 10))
walk[:,0] = 0
walk.cumsum(axis =1)
print walk
# Out:
# [[ 0.         -0.06403787 -0.49663143  0.3632077   0.78873452  0.32052274
#    0.00316991 -0.08032901 -0.01335021  0.04257316]
#  [ 0.         -0.48734015  0.13251973  0.50911387 -0.92115331 -0.80695582
#    0.67924226 -0.80462369 -0.04525463  0.96506599]]

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.plot(walk.T);
